# %% [markdown]
# # **Architecture 2: UNET-Xception**

# %%
from torchvision.datasets import VOCSegmentation
from torchvision.transforms.functional import to_tensor,to_pil_image
from PIL import Image
import os
import numpy as np
from torch.utils.data import Dataset
import torch
import numpy as np
from skimage.segmentation import mark_boundaries
import matplotlib.pylab as plt
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.optim as optim
import albumentations as alb
from torch import nn
from torch import optim

# %%
# !pip install segmentation_models_pytorch
import segmentation_models_pytorch as smp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 410 kB/s eta 0:00:01
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 940 kB/s eta 0:00:01
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 872 kB/s eta 0:00:01
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torchvision>=0.5.0 in /home/faraz/.local/lib/python3.6/site-packages (from segmentation_models_pytorch) (0.5.0)
# Requirement already satisfied: torch in /home/faraz/.local/lib/python3.6/site-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.4.0)
# Requirement already satisfied: munch in /home/faraz/.local/lib/python3.6/site-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: tqdm in /home/faraz/.local/lib/python3.6/site-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.56.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (6.2.2)
# Requirement already satisfied: six in /home/faraz/.local/lib/python3.6/site-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.15.0)
# Requirement already satisfied: numpy in /home/faraz/.local/lib/python3.6/site-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.19.5)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12419 sha256=e5df3dbf3838778c2a2b11c679868e0ae898f6e72e9d14b70f6b290d39766ed6
#   Stored in directory: /home/faraz/.cache/pip/wheels/1c/07/d1/ff77968842daae1dde944173a8e8a7be193646d37842f13b24
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=f3f4c575b916b733b961fcd616189719ff119b512a5d07d6131d2e2bcf2bfd0c
#   Stored in directory: /home/faraz/.cache/pip/wheels/9c/03/81/494596f1d017bbf80daf53bc33dbb05aaa5a6ad6d44c74011f
# Successfully built efficientnet-pytorch pretrainedmodels
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# Installing collected packages: timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# Successfully installed efficientnet-pytorch-0.6.3 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/faraz/.local/lib/python3.6/site-packages)
# WARNING: You are using pip version 21.2.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# **Dataset**

# %%
class custom_dataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_path = os.path.join(self.image_dir, self.images[index])
        mask_path = os.path.join(self.mask_dir, self.images[index])
        img = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path)

        if self.transform is not None:
          augmented= self.transform(image=np.array(img),
          mask=np.array(mask))
          img = augmented['image']
          mask = augmented['mask']
          mask[mask>11]=0

          img= to_tensor(img)
          mask= torch.from_numpy(mask).type(torch.long)

        return img,mask

# %%
TRAIN_IMG_DIR = "A3_Dataset/dataset1/images_prepped_train/"
TRAIN_MASK_DIR = "A3_Dataset/dataset1/annotations_prepped_train/"
VAL_IMG_DIR = "A3_Dataset/dataset1/images_prepped_test/"
VAL_MASK_DIR = "A3_Dataset/dataset1/annotations_prepped_test/"

# %% [markdown]
# **Data Augmentation**

# %%
train_transform = alb.Compose(
        [
            alb.Resize(height=224, width=224),
            alb.Rotate(limit=35, p=1.0),
            alb.HorizontalFlip(p=0.5),
            alb.VerticalFlip(p=0.1),
            alb.Normalize(
                mean=[0.0, 0.0, 0.0],
                std=[1.0, 1.0, 1.0],
                max_pixel_value=255.0,
            ),
        ],
    )
val_transform = alb.Compose(
        [
            alb.Resize(height=224, width=224),
            alb.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
            ),
        ],
    )

# %%
train_ds=custom_dataset( image_dir=TRAIN_IMG_DIR,mask_dir=TRAIN_MASK_DIR,
 transform=train_transform)
val_ds=custom_dataset( image_dir=VAL_IMG_DIR,mask_dir=VAL_MASK_DIR,
 transform=val_transform)

# %%
# %matplotlib inline
np.random.seed(0)
num_classes=11
COLORS = np.random.randint(0, 2, size=(num_classes+1,
3),dtype="uint8")

# %% [markdown]
# **Helper Function to visulaize images and mask**

# %%
def show_img_target(img, target):
    if torch.is_tensor(img):
      img=to_pil_image(img)
      target=target.numpy()
    for ll in range(num_classes):
      mask=(target==ll)
      img=mark_boundaries(np.array(img),mask,outline_color=COLORS[ll],color=COLORS[ll])
    plt.imshow(img)

def re_normalize (x, mean = [0.485, 0.456, 0.406], std= [0.229, 0.224, 0.225]):
   x_r= x.clone()
   for c, (mean_c, std_c) in enumerate(zip(mean, std)):
     x_r [c] *= std_c
     x_r [c] += mean_c
     return x_r

# %%
img, mask = train_ds[53]

# %% [markdown]
# **Data Loader**

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=8, shuffle=False)

# %% [markdown]
# **UNET-Xception**

# %%
model = smp.Unet(
    encoder_name="xception",        
    in_channels=3,                  
    classes=12,                    
)

# %% [markdown]
# **Loss Function and Optimizer**

# %%
criterion = nn.CrossEntropyLoss(reduction="sum")
opt = optim.Adam(model.parameters(), lr=3E-4)

# %% [markdown]
# **Performance Measures**

# %%
def dice_loss1(input, target):
    smooth = 1.
    input=torch.argmax(input, dim=1)
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    
    return ((2. * intersection + smooth) /
              (iflat.sum() + tflat.sum() + smooth)).item()

# %%
def iou(outputs, labels):
    SMOOTH= 1e-6
    outputs=torch.argmax(outputs, dim=1)
    
    intersection = (outputs & labels).float().sum((1, 2)) 
    union = (outputs | labels).float().sum((1, 2))         
    
    iou = (intersection + SMOOTH) / (union + SMOOTH)
    mean_iou=torch.sum(iou)/4 
    return mean_iou.item()

# %%
def metrics_batch(pred, target):
  pred=torch.argmax(pred, dim=1)
  metric=dice_loss1(pred, target)
  return metric

# %%
def loss_batch(loss_func, output, target, opt=None):
 loss = loss_func(output, target)

 with torch.no_grad():
        metric_b=dice_loss1(output, target)
        iou_score=iou(output,target)

 if opt is not None:
   opt.zero_grad()
   loss.backward()
   opt.step()
 return loss.item(), metric_b,iou_score

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5,
patience=20,verbose=1)

# %%
def get_lr(opt):
 for param_group in opt.param_groups:
   return param_group['lr']
current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
 running_loss=0.0
 running_metric=0.0
 running_iou=0.0
 len_data=len(dataset_dl.dataset)
 for xb, yb in dataset_dl:
   output=model(xb)
   loss_b, metric_b,iou_score = loss_batch(loss_func, output, yb, opt)
   running_loss += loss_b

   if metric_b is not None:
     running_metric+=metric_b
     if iou_score is not None:
      running_iou+=metric_b
   if sanity_check is True:
     break
 loss=running_loss/float(len_data)
 metric=running_metric/float(len_data)
 iou=running_iou/float(len_data)
 return loss, metric,iou

# %%
import copy
def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    loss_history={
        "train": [],
        "val": []}
    
    metric_history={
        "train": [],
        "val": []}
    iou_history={
        "train": [],
        "val": []}  
    
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss=float('inf')    
    
    for epoch in range(num_epochs):
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   

        model.train()
        train_loss, train_metric,train_iou=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        iou_history["train"].append(train_iou)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_metric,val_iou=loss_epoch(model,loss_func,val_dl,sanity_check)
       
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)
        iou_history["val"].append(val_iou)   
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            
        print("train loss: %.6f" %(train_loss))
        print("val loss: %.6f" %(val_loss))
        print("-"*10) 
        print(f"Trainig Dice Score {train_metric}")
        print(f"Validation Dice Score {val_metric}")
        print(f"Trainig IOU Score {train_iou}")
        print(f"Validation IOU Score {val_iou}")
    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history,iou_history

# %% [markdown]
# **Training**

# %%
import os
opt = optim.Adam(model.parameters(), lr=1e-6)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models= "./models/"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train={
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": criterion,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": True,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models+"sanity_weights_resnet.pt",
}

model, loss_hist,metric_his,iou_his = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr=1e-06
# Copied best model weights!
# train loss: 1456.879939
# val loss: 10187.915223
# ----------
# Trainig Dice Score 0.009887007991364606
# Validation Dice Score 0.028233655608526552
# Trainig IOU Score 0.009887007991364606
# Validation IOU Score 0.028233655608526552
# Epoch 1/99, current lr=1e-06
# Copied best model weights!
# train loss: 1534.932561
# val loss: 10153.396040
# ----------
# Trainig Dice Score 0.00931285447580613
# Validation Dice Score 0.028950728992424388
# Trainig IOU Score 0.00931285447580613
# Validation IOU Score 0.028950728992424388
# Epoch 2/99, current lr=1e-06
# train loss: 1464.594857
# val loss: 10185.019802
# ----------
# Trainig Dice Score 0.009912131592753148
# Validation Dice Score 0.03018616213656888
# Trainig IOU Score 0.009912131592753148
# Validation IOU Score 0.03018616213656888
# Epoch 3/99, current lr=1e-06
# train loss: 1476.743018
# val loss: 10267.891708
# ----------
# Trainig Dice Score 0.01137820511487914
# Validation Dice Score 0.03132322991248405
# Trainig IOU Score 0.01137820511487914
# Validation IOU Score 0.03132322991248405
# Epoch 4/99, current lr=1e-06
# train loss: 1515.290361
# val loss: 10382.662129
# ----------
# Trainig Dice Score 0.010571632463210934
# Validation Dice Score 0.03206129593424278
# Trainig IOU Score 0.010571632463210934
# Validation IOU Score 0.03206129593424278
# Epoch 5/99, current lr=1e-06
# train loss: 1429.544448
# val loss: 10552.467822
# ----------
# Trainig Dice Score 0.009725310821948973
# Validation Dice Score 0.03255879524910804
# Trainig IOU Score 0.009725310821948973
# Validation IOU Score 0.03255879524910804
# Epoch 6/99, current lr=1e-06
# train loss: 1472.892711
# val loss: 10777.715347
# ----------
# Trainig Dice Score 0.010158340677578377
# Validation Dice Score 0.032639881171802484
# Trainig IOU Score 0.010158340677578377
# Validation IOU Score 0.032639881171802484
# Epoch 7/99, current lr=1e-06
# train loss: 1432.802623
# val loss: 11071.405941
# ----------
# Trainig Dice Score 0.008976825901208197
# Validation Dice Score 0.032224733050506896
# Trainig IOU Score 0.008976825901208197
# Validation IOU Score 0.032224733050506896
# Epoch 8/99, current lr=1e-06
# train loss: 1476.626533
# val loss: 11480.634901
# ----------
# Trainig Dice Score 0.009893122420973609
# Validation Dice Score 0.03128050813580503
# Trainig IOU Score 0.009893122420973609
# Validation IOU Score 0.03128050813580503
# Epoch 9/99, current lr=1e-06
# train loss: 1448.344346
# val loss: 12058.626238
# ----------
# Trainig Dice Score 0.01039833398865744
# Validation Dice Score 0.030752991685772887
# Trainig IOU Score 0.01039833398865744
# Validation IOU Score 0.030752991685772887
# Epoch 10/99, current lr=1e-06
# train loss: 1457.077316
# val loss: 12843.783416
# ----------
# Trainig Dice Score 0.010436685598513736
# Validation Dice Score 0.030258277855297125
# Trainig IOU Score 0.010436685598513736
# Validation IOU Score 0.030258277855297125
# Epoch 11/99, current lr=1e-06
# train loss: 1460.611376
# val loss: 14037.170792
# ----------
# Trainig Dice Score 0.010787875515888433
# Validation Dice Score 0.02994953523768057
# Trainig IOU Score 0.010787875515888433
# Validation IOU Score 0.02994953523768057
# Epoch 12/99, current lr=1e-06
# train loss: 1453.979394
# val loss: 14638.117574
# ----------
# Trainig Dice Score 0.01005130827589321
# Validation Dice Score 0.029684161195660582
# Trainig IOU Score 0.01005130827589321
# Validation IOU Score 0.029684161195660582
# Epoch 13/99, current lr=1e-06
# train loss: 1521.365293
# val loss: 15214.165842
# ----------
# Trainig Dice Score 0.010502279941652386
# Validation Dice Score 0.02965757162264078
# Trainig IOU Score 0.010502279941652386
# Validation IOU Score 0.02965757162264078
# Epoch 14/99, current lr=1e-06
# train loss: 1427.403185
# val loss: 15842.681931
# ----------
# Trainig Dice Score 0.011550508338034315
# Validation Dice Score 0.029712705328913017
# Trainig IOU Score 0.011550508338034315
# Validation IOU Score 0.029712705328913017
# Epoch 15/99, current lr=1e-06
# train loss: 1418.878832
# val loss: 16507.106436
# ----------
# Trainig Dice Score 0.010912436555451852
# Validation Dice Score 0.029987521690897422
# Trainig IOU Score 0.010912436555451852
# Validation IOU Score 0.029987521690897422
# Epoch 16/99, current lr=1e-06
# train loss: 1466.775545
# val loss: 17340.241337
# ----------
# Trainig Dice Score 0.010775041840056957
# Validation Dice Score 0.030196709207969137
# Trainig IOU Score 0.010775041840056957
# Validation IOU Score 0.030196709207969137
# Epoch 17/99, current lr=1e-06
# train loss: 1468.794789
# val loss: 17975.673267
# ----------
# Trainig Dice Score 0.009173534871446988
# Validation Dice Score 0.030380225417637588
# Trainig IOU Score 0.009173534871446988
# Validation IOU Score 0.030380225417637588
# Epoch 18/99, current lr=1e-06
# train loss: 1435.517371
# val loss: 18933.750000
# ----------
# Trainig Dice Score 0.010179435849514579
# Validation Dice Score 0.030605568744168424
# Trainig IOU Score 0.010179435849514579
# Validation IOU Score 0.030605568744168424
# Epoch 19/99, current lr=1e-06
# train loss: 1449.327827
# val loss: 19541.127475
# ----------
# Trainig Dice Score 0.009462515729649516
# Validation Dice Score 0.03057416594854676
# Trainig IOU Score 0.009462515729649516
# Validation IOU Score 0.03057416594854676
# Epoch 20/99, current lr=1e-06
# train loss: 1435.829700
# val loss: 19979.492574
# ----------
# Trainig Dice Score 0.009415847404126576
# Validation Dice Score 0.030506046691743453
# Trainig IOU Score 0.009415847404126576
# Validation IOU Score 0.030506046691743453
# Epoch 21/99, current lr=1e-06
# train loss: 1427.117081
# val loss: 20807.967822
# ----------
# Trainig Dice Score 0.0094126082895887
# Validation Dice Score 0.030470633270716904
# Trainig IOU Score 0.0094126082895887
# Validation IOU Score 0.030470633270716904
# Epoch 22/99, current lr=1e-06
# Epoch 00023: reducing learning rate of group 0 to 5.0000e-07.
# Loading best model weights!
# train loss: 1430.987909
# val loss: 21483.556931
# ----------
# Trainig Dice Score 0.00994429991095852
# Validation Dice Score 0.030408514608250985
# Trainig IOU Score 0.00994429991095852
# Validation IOU Score 0.030408514608250985
# Epoch 23/99, current lr=5e-07
# train loss: 1478.927793
# val loss: 10187.265470
# ----------
# Trainig Dice Score 0.00963246205197368
# Validation Dice Score 0.030153003069433835
# Trainig IOU Score 0.00963246205197368
# Validation IOU Score 0.030153003069433835
# Epoch 24/99, current lr=5e-07
# train loss: 1441.099285
# val loss: 10223.839109
# ----------
# Trainig Dice Score 0.010108698291414765
# Validation Dice Score 0.031335965241536055
# Trainig IOU Score 0.010108698291414765
# Validation IOU Score 0.031335965241536055
# Epoch 25/99, current lr=5e-07
# train loss: 1506.310627
# val loss: 10308.631188
# ----------
# Trainig Dice Score 0.010289746993893824
# Validation Dice Score 0.032055654148064036
# Trainig IOU Score 0.010289746993893824
# Validation IOU Score 0.032055654148064036
# Epoch 26/99, current lr=5e-07
# train loss: 1495.179496
# val loss: 10444.045792
# ----------
# Trainig Dice Score 0.009606790152817396
# Validation Dice Score 0.032252991553580405
# Trainig IOU Score 0.009606790152817396
# Validation IOU Score 0.032252991553580405
# Epoch 27/99, current lr=5e-07
# train loss: 1470.469005
# val loss: 10646.647277
# ----------
# Trainig Dice Score 0.01018095406264635
# Validation Dice Score 0.03242075797354821
# Trainig IOU Score 0.01018095406264635
# Validation IOU Score 0.03242075797354821
# Epoch 28/99, current lr=5e-07
# train loss: 1414.303644
# val loss: 10921.700495
# ----------
# Trainig Dice Score 0.010617796666615666
# Validation Dice Score 0.031973520127853546
# Trainig IOU Score 0.010617796666615666
# Validation IOU Score 0.031973520127853546
# Epoch 29/99, current lr=5e-07
# train loss: 1449.067779
# val loss: 11407.725248
# ----------
# Trainig Dice Score 0.010171671329467108
# Validation Dice Score 0.0315218986851154
# Trainig IOU Score 0.010171671329467108
# Validation IOU Score 0.0315218986851154
# Epoch 30/99, current lr=5e-07
# train loss: 1470.815736
# val loss: 12116.309406
# ----------
# Trainig Dice Score 0.010805491205781942
# Validation Dice Score 0.03065000902308096
# Trainig IOU Score 0.010805491205781942
# Validation IOU Score 0.03065000902308096
# Epoch 31/99, current lr=5e-07
# train loss: 1503.772650
# val loss: 13121.846535
# ----------
# Trainig Dice Score 0.010873375536635397
# Validation Dice Score 0.03010059111189134
# Trainig IOU Score 0.010873375536635397
# Validation IOU Score 0.03010059111189134
# Epoch 32/99, current lr=5e-07
# train loss: 1448.460150
# val loss: 13663.379950
# ----------
# Trainig Dice Score 0.00966147895729834
# Validation Dice Score 0.029661617656745534
# Trainig IOU Score 0.00966147895729834
# Validation IOU Score 0.029661617656745534
# Epoch 33/99, current lr=5e-07
# train loss: 1476.738420
# val loss: 14510.846535
# ----------
# Trainig Dice Score 0.00921385619555897
# Validation Dice Score 0.029478136855776948
# Trainig IOU Score 0.00921385619555897
# Validation IOU Score 0.029478136855776948
# Epoch 34/99, current lr=5e-07
# train loss: 1465.226158
# val loss: 15356.601485
# ----------
# Trainig Dice Score 0.00993119663373651
# Validation Dice Score 0.029420234189175144
# Trainig IOU Score 0.00993119663373651
# Validation IOU Score 0.029420234189175144
# Epoch 35/99, current lr=5e-07
# train loss: 1462.546492
# val loss: 15907.230198
# ----------
# Trainig Dice Score 0.009232157257662157
# Validation Dice Score 0.029459046845388883
# Trainig IOU Score 0.009232157257662157
# Validation IOU Score 0.029459046845388883
# Epoch 36/99, current lr=5e-07
# train loss: 1455.889305
# val loss: 16571.771040
# ----------
# Trainig Dice Score 0.009821919069627975
# Validation Dice Score 0.029542542920254246
# Trainig IOU Score 0.009821919069627975
# Validation IOU Score 0.029542542920254246
# Epoch 37/99, current lr=5e-07
# train loss: 1415.527078
# val loss: 16938.779703
# ----------
# Trainig Dice Score 0.009481430053710938
# Validation Dice Score 0.029586437905188834
# Trainig IOU Score 0.009481430053710938
# Validation IOU Score 0.029586437905188834
# Epoch 38/99, current lr=5e-07
# train loss: 1489.250681
# val loss: 17619.969059
# ----------
# Trainig Dice Score 0.009974570625159655
# Validation Dice Score 0.02992996130839433
# Trainig IOU Score 0.009974570625159655
# Validation IOU Score 0.02992996130839433
# Epoch 39/99, current lr=5e-07
# train loss: 1481.992337
# val loss: 18320.410891
# ----------
# Trainig Dice Score 0.009128171676511011
# Validation Dice Score 0.030053303973509533
# Trainig IOU Score 0.009128171676511011
# Validation IOU Score 0.030053303973509533
# Epoch 40/99, current lr=5e-07
# train loss: 1486.930177
# val loss: 19113.127475
# ----------
# Trainig Dice Score 0.011012450225996387
# Validation Dice Score 0.030017781965803392
# Trainig IOU Score 0.011012450225996387
# Validation IOU Score 0.030017781965803392
# Epoch 41/99, current lr=5e-07
# train loss: 1456.267371
# val loss: 20006.383663
# ----------
# Trainig Dice Score 0.01038570495002601
# Validation Dice Score 0.03024030912040484
# Trainig IOU Score 0.01038570495002601
# Validation IOU Score 0.03024030912040484
# Epoch 42/99, current lr=5e-07
# train loss: 1477.332936
# val loss: 20480.964109
# ----------
# Trainig Dice Score 0.010862735051874893
# Validation Dice Score 0.030430090309369683
# Trainig IOU Score 0.010862735051874893
# Validation IOU Score 0.030430090309369683
# Epoch 43/99, current lr=5e-07
# Epoch 00044: reducing learning rate of group 0 to 2.5000e-07.
# Loading best model weights!
# train loss: 1472.387772
# val loss: 21835.797030
# ----------
# Trainig Dice Score 0.011013225898430847
# Validation Dice Score 0.030557493172069586
# Trainig IOU Score 0.011013225898430847
# Validation IOU Score 0.030557493172069586
# Epoch 44/99, current lr=2.5e-07
# train loss: 1444.419278
# val loss: 10176.572401
# ----------
# Trainig Dice Score 0.009956014253787839
# Validation Dice Score 0.030144018701987692
# Trainig IOU Score 0.009956014253787839
# Validation IOU Score 0.030144018701987692
# Epoch 45/99, current lr=2.5e-07
# train loss: 1452.653610
# val loss: 10231.991955
# ----------
# Trainig Dice Score 0.01048820480014063
# Validation Dice Score 0.03130931665401648
# Trainig IOU Score 0.01048820480014063
# Validation IOU Score 0.03130931665401648
# Epoch 46/99, current lr=2.5e-07
# train loss: 1455.773331
# val loss: 10359.584158
# ----------
# Trainig Dice Score 0.009353798806504917
# Validation Dice Score 0.03194536785087963
# Trainig IOU Score 0.009353798806504917
# Validation IOU Score 0.03194536785087963
# Epoch 47/99, current lr=2.5e-07
# train loss: 1475.768222
# val loss: 10498.154703
# ----------
# Trainig Dice Score 0.009505135486821062
# Validation Dice Score 0.032279168025101765
# Trainig IOU Score 0.009505135486821062
# Validation IOU Score 0.032279168025101765
# Epoch 48/99, current lr=2.5e-07
# train loss: 1452.790872
# val loss: 10757.920792
# ----------
# Trainig Dice Score 0.01108707069376184
# Validation Dice Score 0.032336006070127585
# Trainig IOU Score 0.01108707069376184
# Validation IOU Score 0.032336006070127585
# Epoch 49/99, current lr=2.5e-07
# train loss: 1480.693460
# val loss: 11010.657178
# ----------
# Trainig Dice Score 0.008304570611231334
# Validation Dice Score 0.032069605175811464
# Trainig IOU Score 0.008304570611231334
# Validation IOU Score 0.032069605175811464
# Epoch 50/99, current lr=2.5e-07
# train loss: 1464.981437
# val loss: 11416.743812
# ----------
# Trainig Dice Score 0.010957480126570615
# Validation Dice Score 0.03146172277998216
# Trainig IOU Score 0.010957480126570615
# Validation IOU Score 0.03146172277998216
# Epoch 51/99, current lr=2.5e-07
# train loss: 1421.526141
# val loss: 11875.292079
# ----------
# Trainig Dice Score 0.009901501502263124
# Validation Dice Score 0.030834330190526376
# Trainig IOU Score 0.009901501502263124
# Validation IOU Score 0.030834330190526376
# Epoch 52/99, current lr=2.5e-07
# train loss: 1474.120061
# val loss: 12791.251238
# ----------
# Trainig Dice Score 0.01018560030155026
# Validation Dice Score 0.030036546216152683
# Trainig IOU Score 0.01018560030155026
# Validation IOU Score 0.030036546216152683
# Epoch 53/99, current lr=2.5e-07
# train loss: 1484.002725
# val loss: 13716.742574
# ----------
# Trainig Dice Score 0.010224611947581943
# Validation Dice Score 0.02951793859500696
# Trainig IOU Score 0.010224611947581943
# Validation IOU Score 0.02951793859500696
# Epoch 54/99, current lr=2.5e-07
# train loss: 1429.744550
# val loss: 14482.189356
# ----------
# Trainig Dice Score 0.009965534755904278
# Validation Dice Score 0.029242945189523226
# Trainig IOU Score 0.009965534755904278
# Validation IOU Score 0.029242945189523226
# Epoch 55/99, current lr=2.5e-07
# train loss: 1498.486035
# val loss: 14981.777228
# ----------
# Trainig Dice Score 0.010233219053180082
# Validation Dice Score 0.02916290264318485
# Trainig IOU Score 0.010233219053180082
# Validation IOU Score 0.02916290264318485
# Epoch 56/99, current lr=2.5e-07
# train loss: 1486.275375
# val loss: 15670.726485
# ----------
# Trainig Dice Score 0.009664988322868658
# Validation Dice Score 0.029229971441892114
# Trainig IOU Score 0.009664988322868658
# Validation IOU Score 0.029229971441892114
# Epoch 57/99, current lr=2.5e-07
# train loss: 1496.448910
# val loss: 16707.165842
# ----------
# Trainig Dice Score 0.011395185454989649
# Validation Dice Score 0.02966781181864219
# Trainig IOU Score 0.011395185454989649
# Validation IOU Score 0.02966781181864219
# Epoch 58/99, current lr=2.5e-07
# train loss: 1445.054666
# val loss: 17691.700495
# ----------
# Trainig Dice Score 0.009650106326111007
# Validation Dice Score 0.02996103834397722
# Trainig IOU Score 0.009650106326111007
# Validation IOU Score 0.02996103834397722
# Epoch 59/99, current lr=2.5e-07
# train loss: 1446.350307
# val loss: 18576.774752
# ----------
# Trainig Dice Score 0.0101010273198016
# Validation Dice Score 0.03008328097881657
# Trainig IOU Score 0.0101010273198016
# Validation IOU Score 0.03008328097881657
# Epoch 60/99, current lr=2.5e-07
# train loss: 1479.243869
# val loss: 19291.649752
# ----------
# Trainig Dice Score 0.010197081422935714
# Validation Dice Score 0.030209829311559695
# Trainig IOU Score 0.010197081422935714
# Validation IOU Score 0.030209829311559695
# Epoch 61/99, current lr=2.5e-07
# train loss: 1436.296322
# val loss: 20004.004950
# ----------
# Trainig Dice Score 0.009832288653714131
# Validation Dice Score 0.030254552860071164
# Trainig IOU Score 0.009832288653714131
# Validation IOU Score 0.030254552860071164
# Epoch 62/99, current lr=2.5e-07
# train loss: 1484.554155
# val loss: 21822.787129
# ----------
# Trainig Dice Score 0.009488869752805953
# Validation Dice Score 0.030256776526422783
# Trainig IOU Score 0.009488869752805953
# Validation IOU Score 0.030256776526422783
# Epoch 63/99, current lr=2.5e-07
# train loss: 1465.317950
# val loss: 22244.351485
# ----------
# Trainig Dice Score 0.0102795008417696
# Validation Dice Score 0.03016812258427686
# Trainig IOU Score 0.0102795008417696
# Validation IOU Score 0.03016812258427686
# Epoch 64/99, current lr=2.5e-07
# Epoch 00065: reducing learning rate of group 0 to 1.2500e-07.
# Loading best model weights!
# train loss: 1458.966792
# val loss: 22549.811881
# ----------
# Trainig Dice Score 0.009201729330120034
# Validation Dice Score 0.03007199976703908
# Trainig IOU Score 0.009201729330120034
# Validation IOU Score 0.03007199976703908
# Epoch 65/99, current lr=1.25e-07
# Copied best model weights!
# train loss: 1433.580892
# val loss: 10140.228342
# ----------
# Trainig Dice Score 0.01013447218435012
# Validation Dice Score 0.030054040474466758
# Trainig IOU Score 0.01013447218435012
# Validation IOU Score 0.030054040474466758
# Epoch 66/99, current lr=1.25e-07
# train loss: 1438.452657
# val loss: 10195.366955
# ----------
# Trainig Dice Score 0.010106547327067611
# Validation Dice Score 0.03134490711854236
# Trainig IOU Score 0.010106547327067611
# Validation IOU Score 0.03134490711854236
# Epoch 67/99, current lr=1.25e-07
# train loss: 1454.124830
# val loss: 10298.142946
# ----------
# Trainig Dice Score 0.008368329066346712
# Validation Dice Score 0.032088178219181474
# Trainig IOU Score 0.008368329066346712
# Validation IOU Score 0.032088178219181474
# Epoch 68/99, current lr=1.25e-07
# train loss: 1477.459128
# val loss: 10484.764851
# ----------
# Trainig Dice Score 0.009203743220025252
# Validation Dice Score 0.03252838861824262
# Trainig IOU Score 0.009203743220025252
# Validation IOU Score 0.03252838861824262
# Epoch 69/99, current lr=1.25e-07
# train loss: 1461.199932
# val loss: 10796.238861
# ----------
# Trainig Dice Score 0.010012345353004394
# Validation Dice Score 0.0325143290038156
# Trainig IOU Score 0.010012345353004394
# Validation IOU Score 0.0325143290038156
# Epoch 70/99, current lr=1.25e-07
# train loss: 1461.273672
# val loss: 11173.537129
# ----------
# Trainig Dice Score 0.009961201644398536
# Validation Dice Score 0.03210160519817088
# Trainig IOU Score 0.009961201644398536
# Validation IOU Score 0.03210160519817088
# Epoch 71/99, current lr=1.25e-07
# train loss: 1478.642200
# val loss: 11502.605198
# ----------
# Trainig Dice Score 0.010419972910868049
# Validation Dice Score 0.03163326140677575
# Trainig IOU Score 0.010419972910868049
# Validation IOU Score 0.03163326140677575
# Epoch 72/99, current lr=1.25e-07
# train loss: 1491.334980
# val loss: 12074.696782
# ----------
# Trainig Dice Score 0.009518395977384063
# Validation Dice Score 0.03102381394641234
# Trainig IOU Score 0.009518395977384063
# Validation IOU Score 0.03102381394641234
# Epoch 73/99, current lr=1.25e-07
# train loss: 1404.072292
# val loss: 12823.693069
# ----------
# Trainig Dice Score 0.010716574068615157
# Validation Dice Score 0.030492279789235334
# Trainig IOU Score 0.010716574068615157
# Validation IOU Score 0.030492279789235334
# Epoch 74/99, current lr=1.25e-07
# train loss: 1472.008515
# val loss: 13700.971535
# ----------
# Trainig Dice Score 0.01077369643167189
# Validation Dice Score 0.02982446226743188
# Trainig IOU Score 0.01077369643167189
# Validation IOU Score 0.02982446226743188
# Epoch 75/99, current lr=1.25e-07
# train loss: 1468.889135
# val loss: 14424.248762
# ----------
# Trainig Dice Score 0.008648847689095894
# Validation Dice Score 0.029470693947064995
# Trainig IOU Score 0.008648847689095894
# Validation IOU Score 0.029470693947064995
# Epoch 76/99, current lr=1.25e-07
# train loss: 1484.774693
# val loss: 15224.491337
# ----------
# Trainig Dice Score 0.009992223344641745
# Validation Dice Score 0.029641916256139773
# Trainig IOU Score 0.009992223344641745
# Validation IOU Score 0.029641916256139773
# Epoch 77/99, current lr=1.25e-07
# train loss: 1420.141434
# val loss: 15748.664604
# ----------
# Trainig Dice Score 0.010204644553992663
# Validation Dice Score 0.029382495596857353
# Trainig IOU Score 0.010204644553992663
# Validation IOU Score 0.029382495596857353
# Epoch 78/99, current lr=1.25e-07
# train loss: 1481.363249
# val loss: 16137.775990
# ----------
# Trainig Dice Score 0.00975913637665377
# Validation Dice Score 0.02936297360033092
# Trainig IOU Score 0.00975913637665377
# Validation IOU Score 0.02936297360033092
# Epoch 79/99, current lr=1.25e-07
# train loss: 1496.414339
# val loss: 17069.811881
# ----------
# Trainig Dice Score 0.009813048859058348
# Validation Dice Score 0.02940932594903625
# Trainig IOU Score 0.009813048859058348
# Validation IOU Score 0.02940932594903625
# Epoch 80/99, current lr=1.25e-07
# train loss: 1419.412636
# val loss: 17598.969059
# ----------
# Trainig Dice Score 0.009492387563721037
# Validation Dice Score 0.029719628910026927
# Trainig IOU Score 0.009492387563721037
# Validation IOU Score 0.029719628910026927
# Epoch 81/99, current lr=1.25e-07
# train loss: 1448.316928
# val loss: 18305.655941
# ----------
# Trainig Dice Score 0.009333272720877417
# Validation Dice Score 0.029703704437406938
# Trainig IOU Score 0.009333272720877417
# Validation IOU Score 0.029703704437406938
# Epoch 82/99, current lr=1.25e-07
# train loss: 1476.723263
# val loss: 18866.886139
# ----------
# Trainig Dice Score 0.009368864002279754
# Validation Dice Score 0.029769758186718023
# Trainig IOU Score 0.009368864002279754
# Validation IOU Score 0.029769758186718023
# Epoch 83/99, current lr=1.25e-07
# train loss: 1496.220027
# val loss: 19575.715347
# ----------
# Trainig Dice Score 0.010118446168197922
# Validation Dice Score 0.029966160802557918
# Trainig IOU Score 0.010118446168197922
# Validation IOU Score 0.029966160802557918
# Epoch 84/99, current lr=1.25e-07
# train loss: 1431.528440
# val loss: 20933.445545
# ----------
# Trainig Dice Score 0.010268063896033679
# Validation Dice Score 0.03015270799693495
# Trainig IOU Score 0.010268063896033679
# Validation IOU Score 0.03015270799693495
# Epoch 85/99, current lr=1.25e-07
# train loss: 1472.004087
# val loss: 22691.539604
# ----------
# Trainig Dice Score 0.01042613476433611
# Validation Dice Score 0.03029203178858993
# Trainig IOU Score 0.01042613476433611
# Validation IOU Score 0.03029203178858993
# Epoch 86/99, current lr=1.25e-07
# Epoch 00087: reducing learning rate of group 0 to 6.2500e-08.
# Loading best model weights!
# train loss: 1468.189373
# val loss: 24304.081683
# ----------
# Trainig Dice Score 0.00989446977828439
# Validation Dice Score 0.030307727284950785
# Trainig IOU Score 0.00989446977828439
# Validation IOU Score 0.030307727284950785
# Epoch 87/99, current lr=6.25e-08
# train loss: 1465.316417
# val loss: 10214.183168
# ----------
# Trainig Dice Score 0.009947629325721179
# Validation Dice Score 0.031006078908939173
# Trainig IOU Score 0.009947629325721179
# Validation IOU Score 0.031006078908939173
# Epoch 88/99, current lr=6.25e-08
# train loss: 1488.890327
# val loss: 10349.741955
# ----------
# Trainig Dice Score 0.010110108014348418
# Validation Dice Score 0.031690632942879556
# Trainig IOU Score 0.010110108014348418
# Validation IOU Score 0.031690632942879556
# Epoch 89/99, current lr=6.25e-08
# train loss: 1478.212875
# val loss: 10551.341584
# ----------
# Trainig Dice Score 0.009840214284954019
# Validation Dice Score 0.03205184889311838
# Trainig IOU Score 0.009840214284954019
# Validation IOU Score 0.03205184889311838
# Epoch 90/99, current lr=6.25e-08
# train loss: 1420.164595
# val loss: 10820.089109
# ----------
# Trainig Dice Score 0.009595368798487193
# Validation Dice Score 0.032120893497278195
# Trainig IOU Score 0.009595368798487193
# Validation IOU Score 0.032120893497278195
# Epoch 91/99, current lr=6.25e-08
# train loss: 1486.026737
# val loss: 11141.987624
# ----------
# Trainig Dice Score 0.009818077737044248
# Validation Dice Score 0.03186536071324112
# Trainig IOU Score 0.009818077737044248
# Validation IOU Score 0.03186536071324112
# Epoch 92/99, current lr=6.25e-08
# train loss: 1464.493018
# val loss: 11611.662129
# ----------
# Trainig Dice Score 0.009477464639523373
# Validation Dice Score 0.031432758463491306
# Trainig IOU Score 0.009477464639523373
# Validation IOU Score 0.031432758463491306
# Epoch 93/99, current lr=6.25e-08
# train loss: 1453.138794
# val loss: 12143.549505
# ----------
# Trainig Dice Score 0.010272774449486174
# Validation Dice Score 0.030717670327365987
# Trainig IOU Score 0.010272774449486174
# Validation IOU Score 0.030717670327365987
# Epoch 94/99, current lr=6.25e-08
# train loss: 1428.912125
# val loss: 12798.158416
# ----------
# Trainig Dice Score 0.010927218507356149
# Validation Dice Score 0.02997174593481687
# Trainig IOU Score 0.010927218507356149
# Validation IOU Score 0.02997174593481687
# Epoch 95/99, current lr=6.25e-08
# train loss: 1508.214918
# val loss: 13708.996287
# ----------
# Trainig Dice Score 0.010306145904499438
# Validation Dice Score 0.029274888557962852
# Trainig IOU Score 0.010306145904499438
# Validation IOU Score 0.029274888557962852
# Epoch 96/99, current lr=6.25e-08
# train loss: 1426.768392
# val loss: 14413.428218
# ----------
# Trainig Dice Score 0.011711729969575554
# Validation Dice Score 0.029200072335724782
# Trainig IOU Score 0.011711729969575554
# Validation IOU Score 0.029200072335724782
# Epoch 97/99, current lr=6.25e-08
# train loss: 1469.753065
# val loss: 14879.988861
# ----------
# Trainig Dice Score 0.009991551614912069
# Validation Dice Score 0.029572961354019617
# Trainig IOU Score 0.009991551614912069
# Validation IOU Score 0.029572961354019617
# Epoch 98/99, current lr=6.25e-08
# train loss: 1429.856778
# val loss: 15185.696782
# ----------
# Trainig Dice Score 0.00915413266631498
# Validation Dice Score 0.029455583874541936
# Trainig IOU Score 0.00915413266631498
# Validation IOU Score 0.029455583874541936
# Epoch 99/99, current lr=6.25e-08
# train loss: 1475.169278
# val loss: 15711.879950
# ----------
# Trainig Dice Score 0.010240242331814052
# Validation Dice Score 0.02955926999007121
# Trainig IOU Score 0.010240242331814052
# Validation IOU Score 0.02955926999007121

# %% [markdown]
# **Plotting performance measures**

# %%
num_epochs=params_train["num_epochs"]

plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
plt.title("Train-Val Dice Coefficient")
plt.plot(range(1,num_epochs+1),metric_his["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_his["val"],label="val")
plt.ylabel("Dice Coefficient")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
plt.title("Train-Val IOU")
plt.plot(range(1,num_epochs+1),iou_his["train"],label="train")
plt.plot(range(1,num_epochs+1),iou_his["val"],label="val")
plt.ylabel("IOU")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %% [markdown]
# **Qualitative Results**

# %%
img_1, mask_1 = val_ds[47]
img_2, mask_2 = val_ds[21]
img_3, mask_3 = val_ds[11]
img_4, mask_4 = val_ds[41]

# %%
def get_prediction(img):
  img=torch.unsqueeze(img, 0)
  prediction=model(img)
  prediction = torch.nn.functional.softmax(prediction, dim=1)
  prediction=torch.squeeze(prediction)
  prediction=torch.argmax(prediction, dim=0)
  return prediction

# %% [markdown]
# **Image 1**

# %%
pred_1=get_prediction(img_1)

# %%
plt.figure(figsize=(20,20))
img_r= re_normalize(img_1)
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(to_pil_image(img_r))
plt.subplot(1, 3, 2)
plt.title('Ground Truth Mask')
plt.imshow(mask_1)
plt.subplot(1, 3, 3)
plt.title('Ground Truth Mask super imposed on original image')
show_img_target(img_r, mask_1)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1)
plt.title('Predicted Mask')
plt.imshow(pred_1)
plt.subplot(1, 2, 2)
plt.title('Predicted mask super imposed on image')
show_img_target(img_r, pred_1)

# %% [markdown]
# **Image 2**

# %%
pred_2=get_prediction(img_2)

# %%
plt.figure(figsize=(20,20))
img_r= re_normalize(img_2)
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(to_pil_image(img_r))
plt.subplot(1, 3, 2)
plt.title('Ground Truth Mask')
plt.imshow(mask_2)
plt.subplot(1, 3, 3)
plt.title('Ground Truth Mask super imposed on original image')
show_img_target(img_r, mask_2)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1)
plt.title('Predicted Mask')
plt.imshow(pred_2)
plt.subplot(1, 2, 2)
plt.title('Predicted mask super imposed on image')
show_img_target(img_r, pred_2)

# %% [markdown]
# **Image 3**

# %%
pred_3=get_prediction(img_3)

# %%
plt.figure(figsize=(20,20))
img_r= re_normalize(img_2)
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(to_pil_image(img_r))
plt.subplot(1, 3, 2)
plt.title('Ground Truth Mask')
plt.imshow(mask_3)
plt.subplot(1, 3, 3)
plt.title('Ground Truth Mask super imposed on original image')
show_img_target(img_r, mask_3)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1)
plt.title('Predicted Mask')
plt.imshow(pred_3)
plt.subplot(1, 2, 2)
plt.title('Predicted mask super imposed on image')
show_img_target(img_r, pred_3)

# %% [markdown]
# **Image 4**

# %%
pred_4=get_prediction(img_4)

# %%
plt.figure(figsize=(20,20))
img_r= re_normalize(img_4)
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(to_pil_image(img_r))
plt.subplot(1, 3, 2)
plt.title('Ground Truth Mask')
plt.imshow(mask_4)
plt.subplot(1, 3, 3)
plt.title('Ground Truth Mask super imposed on original image')
show_img_target(img_r, mask_4)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1)
plt.title('Predicted Mask')
plt.imshow(pred_4)
plt.subplot(1, 2, 2)
plt.title('Predicted mask super imposed on image')
show_img_target(img_r, pred_4)
